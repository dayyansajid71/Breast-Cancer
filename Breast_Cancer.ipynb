# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-28e65652-6456-4d9a-bd06-9dc5574fcf58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28e65652-6456-4d9a-bd06-9dc5574fcf58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df= pd.read_csv("data.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.values
# Out:
# array([[842302, 'M', 17.99, ..., 0.4601, 0.1189, nan],
#        [842517, 'M', 20.57, ..., 0.275, 0.08902, nan],
#        [84300903, 'M', 19.69, ..., 0.3613, 0.08758, nan],
#        ...,
#        [926954, 'M', 16.6, ..., 0.2218, 0.0782, nan],
#        [927241, 'M', 20.6, ..., 0.4087, 0.124, nan],
#        [92751, 'B', 7.76, ..., 0.2871, 0.07039, nan]], dtype=object)

# %%
# Remove all duplicate rows
df.drop_duplicates(inplace=True)

# %%
df = df.drop(columns=['Unnamed: 32'])

# %%
x=df.drop(columns=['diagnosis'])
y=df['diagnosis']

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
model.predict(x)
# Out:
# array(['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
# ...

# %%
predictions=model.predict(x)
predictions
# Out:
# array(['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
train_test_split(x,y,test_size=0.2)
# Out:
# [           id  radius_mean  texture_mean  perimeter_mean  area_mean  \
#  208   8810158       13.110         22.54           87.02      529.4
#  379   9013838       11.080         18.83           73.30      361.6
#  18     849014       19.810         22.15          130.00     1260.0
#  78    8610862       20.180         23.97          143.70     1245.0
#  227  88147102       15.000         15.51           97.45      684.5
#  ..        ...          ...           ...             ...        ...
#  484    912600       15.730         11.28          102.80      747.2
#  419    906290       11.160         21.41           70.95      380.3
#  251  88518501       11.500         18.45           73.28      407.4
#  433    908445       18.820         21.97          123.70     1110.0
#  110    864033        9.777         16.99           62.50      290.2
#
#       smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions=model.predict(x_test)
predictions
# Out:
# array(['B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M',
#        'M', 'M', 'M', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'M',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,predictions)
score
# Out:
# 0.9473684210526315

# %%
import joblib
joblib.dump(model,'breast_cancer_model.joblib')
# Out:
# ['breast_cancer_model.joblib']

# %%
joblib.load('breast_cancer_model.joblib')
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import classification_report
model=joblib.load('breast_cancer_model.joblib')
predictions=model.predict(x_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.99      0.93      0.96        73
#            M       0.89      0.98      0.93        41
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.95      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
from sklearn import tree

# %%
tree.export_graphviz(model,out_file='tree.dot',feature_names=x.columns,class_names=sorted(y.unique()),label='all',rounded=True,filled=True)

# %%
import graphviz
from IPython.display import display

# %%
with open("tree.dot") as f:
    dot_graph = f.read()
# Render and display the graph
display(graphviz.Source(dot_graph))

# %%
from graphviz import Source

# Read the DOT file
with open("tree.dot") as f:
    dot_graph = f.read()

# Create Graphviz source
graph = Source(dot_graph)

# Save as SVG
graph.format = "svg"
graph.render("tree", cleanup=True)  # creates tree.svg
# Out:
# 'tree.svg'

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[68,  5],
#        [ 1, 40]])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Example true and predicted labels
y_true = [0, 1, 0, 1, 0, 1, 1, 0, 1, 0]
y_pred =  [1, 1, 0, 1, 0, 1, 1, 0, 1, 0]

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.title("Confusion Matrix")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
np.random.seed(42)
log2fc = np.random.normal(0, 2, 1000)       # log2 fold change
p_values = np.random.uniform(0.0001, 1, 1000)

# Convert p-values
neg_log_p = -np.log10(p_values)

# Plot
plt.scatter(log2fc, neg_log_p)
plt.xlabel("log2 Fold Change")
plt.ylabel("-log10(p-value)")
plt.title("Volcano Plot")
plt.show()
